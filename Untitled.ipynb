# %%
import librosa
import matplotlib.pyplot as plt

# %%
data, rate = librosa.load("oboe-g4-PB-loop.wav")

# %%
def show_data(data):
    plt.figure()
    plt.plot(data)
    plt.show()
    
show_data(data)

# %%
librosa.feature.m
